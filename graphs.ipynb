# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Car data.csv")

print(df.head())
print(df.tail())

print(df.info())

print(df.describe())

print(df.columns)

# Remove extra spaces from column names
df.columns = df.columns.str.strip()

# Create Brand and Model columns if they don't exist
if "Brand" not in df.columns:
    df["Brand"] = df["Name"].str.split().str[0]

if "Model" not in df.columns:
    df["Model"] = df["Name"].str.split().str[1:].str.join(" ")

print(df["Brand"].unique())
print(df["Brand"].nunique())

print(df["Model"].unique())

print(df.describe().T)
print(df.describe(include="all").T)

df.fillna(0, inplace=True)
# Out:
#                Name  Min Price (Lakh)  Max Price (Lakh)  Range (kmpl)    CC  \
# 0     Mahindra Thar             11.35             17.60         15.20  1497
# 1      Maruti Swift              6.49              9.60         24.80  1197
# 2  Mahindra Scorpio             13.62             17.42         22.00  2184
# 3        Tata Punch              6.13             10.20         20.09  1199
# 4     Hyundai Creta             11.00             20.15         17.40  1497
#
#    Seats  Variants     Type  Ex-Showroom Price       RTO  Insurance  Other  \
# 0      4        19   Petrol            1430000  143000.0    84367.0  14300
# 1      5        11   Petrol             649000   46240.0    27791.0   5485
# 2      7         4  Diesel             1361600  175000.0    85943.0  27532
# 3      5        25   Petrol             612900   42903.0    35311.0      0
# 4      5        28   Petrol            1099900  116863.0    45300.0  11599
#
#   Onroad Price
# 0    16,71,667
# 1     7,28,516
# ...

# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv("Car data.csv")

# Create Brand and Model columns from Car Name
df["Brand"] = df["Name"].str.split().str[0]
df["Model"] = df["Name"].str.split().str[1]

# Set manufacturing date range
start_date = pd.to_datetime("2010-01-01")
end_date = pd.to_datetime("2026-01-01")

# Find total days between dates
days = (end_date - start_date).days

# Generate random manufacturing dates
random_days = np.random.randint(0, days, len(df))
df["Manufacturing Date"] = start_date + pd.to_timedelta(random_days, unit="D")

# Calculate car age
today = pd.to_datetime("today")
df["Age Days"] = (today - df["Manufacturing Date"]).dt.days

# Convert days into years
df["Car Age"] = round(df["Age Days"] / 365.25, 2)

# Display data
print(df.head())
# Out:
#                Name  Min Price (Lakh)  Max Price (Lakh)  Range (kmpl)    CC  \
# 0     Mahindra Thar             11.35             17.60         15.20  1497
# 1      Maruti Swift              6.49              9.60         24.80  1197
# 2  Mahindra Scorpio             13.62             17.42         22.00  2184
# 3        Tata Punch              6.13             10.20         20.09  1199
# 4     Hyundai Creta             11.00             20.15         17.40  1497
#
#    Seats  Variants     Type  Ex-Showroom Price       RTO  Insurance  Other  \
# 0      4        19   Petrol            1430000  143000.0    84367.0  14300
# 1      5        11   Petrol             649000   46240.0    27791.0   5485
# 2      7         4  Diesel             1361600  175000.0    85943.0  27532
# 3      5        25   Petrol             612900   42903.0    35311.0      0
# 4      5        28   Petrol            1099900  116863.0    45300.0  11599
#
# ...

# %%
import numpy as np

# Calculate total income from Onroad Price
total_income = df["Onroad Price"].sum()
print("Total Income:", total_income)


# Select only numerical columns
num_data = df.select_dtypes(include=np.number)

# Convert DataFrame into NumPy array
arr = num_data.to_numpy()

print("Array Shape:", arr.shape)
print("Array Size:", arr.size)


# Find highest Onroad Price
highest_price = np.max(df["Onroad Price"])
print("Highest Onroad Price:", highest_price)


# Find lowest mileage
lowest_mileage = np.min(df["Range (kmpl)"])
print("Lowest Mileage:", lowest_mileage)


# Calculate average engine capacity
avg_engine = np.mean(df["CC"])
print("Average Engine Capacity:", round(avg_engine, 2))
# Out:
# Total Income: 16,71,6677,28,51616,50,0756,91,11412,73,66216,36,0628,98,1859,32,5448,41,75038,77,30511,12,34823,75,1749,68,6651,11,70,2788,39,5467,51,7702,77,25,2956,98,00917,88,39316,13,52212,42,525
# Array Shape: (21, 12)
# Array Size: 252
# Highest Onroad Price: 9,68,665
# Lowest Mileage: 9.2
# Average Engine Capacity: 1690.86

# %%
import matplotlib.pyplot as plt
# barchart
plt.figure(figsize=(10,5))

plt.bar(df["Name"], df["Onroad Price"], color="skyblue")

plt.title("Onroad Price of Cars")
plt.xlabel("Car Name")
plt.ylabel("Onroad Price")

plt.xticks(rotation=45, ha = "right")

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

plt.bar(df["Name"], df["Range (kmpl)"])

plt.title("Mileage Comparison")
plt.xlabel("Car Name")
plt.ylabel("Mileage (kmpl)")

plt.xticks(rotation=45,ha="right")

plt.show()

# %%
#Engine Capacity VS Mileage 
plt.scatter(df["CC"],df["Range (kmpl)"])
plt.title("Engine Capacity VS Mileage ")
plt.xlabel("Engine Capacity (CC)")
plt.ylabel("Range (kmpl)")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(df["Ex-Showroom Price"], bins=10, alpha=0.5, label="Ex-Showroom")
plt.hist(df["Onroad Price"], bins=10, alpha=0.5, label="Onroad Price")

plt.title("Ex-Showroom vs Onroad Price")
plt.xlabel("Price")
plt.ylabel("Number of Cars")
plt.legend()

plt.show()

# %%
#Distribution of Onroad Price 
plt.hist(df["Onroad Price"],bins =5,edgecolor="black")
plt.xlabel("Onroad Price ")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt

# Count the number of cars of each brand
count = df["Brand"].value_counts()

# Labels for pie chart
labels = count.index

# Colors
colors = ['red', 'blue', 'green', 'yellow', 'orange', 'purple', 'pink']

# Plot pie chart
plt.pie(count, labels=labels, colors=colors, autopct='%1.1f%%')

# Title of chart
plt.title("Brand Distribution")

# Make pie chart circular means equal ratio
plt.axis('equal')

# Display chart. for ouput
plt.show()

# %%
sns.heatmap(
    df.corr(numeric_only=True),
    annot=True
)

plt.title("Correlation Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sns.heatmap(
#       2     df.corr(numeric_only=True),
#       3     annot=True
#       4 )
#
# NameError: name 'sns' is not defined
